# %%
import os

os.chdir(r"D:\business_analytics_project1")

print(os.getcwd())
# Out:
# D:\business_analytics_project1

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

# Load final feature-engineered supplier dataset
supplier_features = pd.read_csv(
    "data/processed/supplier_features.csv"
)

print("Supplier Features Shape:", supplier_features.shape)

display(supplier_features.head())
# Out:
# Supplier Features Shape: (40, 14)
#   supplier_id  late_delivery_rate  delivery_reliability  \
# 0      SUP001               42.19                 57.81
# 1      SUP002               71.82                 28.18
# 2      SUP003               66.98                 33.02
# 3      SUP004               43.50                 56.50
# 4      SUP005               66.28                 33.72
#
#    avg_lead_time_variance  lead_time_std  lead_time_instability  \
# 0                    0.17           7.40              -0.486346
# 1                    2.34          10.91               1.593822
# 2                    1.78           9.23               0.789666
# 3                    0.32           6.82              -0.626619
# 4                    2.10           7.43               0.296122
#
#    quality_incident_rate_pct  quality_incidents_per_1000_orders  \
# 0                       0.46                           4.552352
# 1                       1.31                          13.106160
# ...

# %%
print("Features available for risk assessment:")
print(supplier_features.columns.tolist())
# Out:
# Features available for risk assessment:
# ['supplier_id', 'late_delivery_rate', 'delivery_reliability', 'avg_lead_time_variance', 'lead_time_std', 'lead_time_instability', 'quality_incident_rate_pct', 'quality_incidents_per_1000_orders', 'critical_parts_supplied', 'critical_part_share', 'critical_exposure_index', 'total_order_quantity', 'order_quantity_share', 'order_quantity_per_part']
